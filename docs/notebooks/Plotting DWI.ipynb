# %%
# %load_ext autoreload
# %autoreload 2

# %%
import attr
from eddymotion import dmri

# %%
d = dmri.DWI()

# %%
data = dmri.load("/Users/oesteban/sdcflows-tests/ds001771/sub-36/dwi/sub-36_acq-PA_dwi.nii.gz", gradients_file="/Users/oesteban/tmp/sdcflows/rasb.tsv", b0_file="/Users/oesteban/tmp/sdcflows/sub-36_acq-PA_dwi_b0_mcf_ref.nii.gz")

# %%
data.plot_mosaic()

# %%
data.plot_mosaic(index=10)

# %%
data.plot_mosaic(index=100)

# %%
data.to_filename("/Users/oesteban/tmp/sdcflows/tutorial.h5")
