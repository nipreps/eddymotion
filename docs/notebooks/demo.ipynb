# %%
from emc.workflows.correct import init_emc_wf
from pathlib import Path
import nipype.pipeline.engine as pe
from nipype.interfaces import utility as niu
from dipy.data import get_fnames
from dmriprep.workflows.dwi.util import init_dwi_reference_wf
from dmriprep.interfaces.vectors import CheckGradientTable

#fdata, fbvals, fbvecs = get_fnames("sherbrooke_3shell")
#fdata, fbvals, fbvecs = get_fnames("stanford_hardi")
fdata = '/mnt/data/datalad/ds000206/sub-THP0001/ses-THP0001CCF1/dwi/sub-THP0001_ses-THP0001CCF1_acq-GD31_run-01_dwi.nii.gz'
fbvals = '/mnt/data/datalad/ds000206/sub-THP0001/ses-THP0001CCF1/dwi/sub-THP0001_ses-THP0001CCF1_acq-GD31_run-01_dwi.bval'
fbvecs = '/mnt/data/datalad/ds000206/sub-THP0001/ses-THP0001CCF1/dwi/sub-THP0001_ses-THP0001CCF1_acq-GD31_run-01_dwi.bvec'

# %%
# Create a workflow that can be added as a node to
# `~dmriprep.workflows.dwi.base.init_dwi_preproc_wf` and (for now) envelops
# `~dmriprep.workflows.dwi.util.init_dwi_reference_wf`
def build_emc_workflow(fdata, fbvals, fbvecs, work_dir='/tmp'):

    wf_emc = pe.Workflow(name='emc_correction')

    inputnode = pe.Node(niu.IdentityInterface(fields=['dwi_files', 'in_bval',
                                                      'in_bvec']),
        name='inputnode')

    inputnode.inputs.dwi_file = fdata
    inputnode.inputs.in_bval = fbvals
    inputnode.inputs.in_bvec = fbvecs

    emc_wf_node = init_emc_wf('emc_wf')

    wf_emc.connect([
        (inputnode, emc_wf_node, [('dwi_file', 'meta_inputnode.dwi_file'),
                                  ('in_bval', 'meta_inputnode.in_bval'),
                                  ('in_bvec', 'meta_inputnode.in_bvec')])
    ])

    wf_emc.base_dir = work_dir

    cfg = dict(execution={'stop_on_first_crash': False,
                          'parameterize_dirs': True, 'crashfile_format': 'txt',
                          'remove_unnecessary_outputs': False,
                          'poll_sleep_duration': 0, 'plugin': 'MultiProc'})
    for key in cfg.keys():
        for setting, value in cfg[key].items():
            wf_emc.config[key][setting] = value

    return wf_emc

# %%
wf = build_emc_workflow(fdata, fbvals, fbvecs)
res = wf.run(plugin='MultiProc')
# Out:
# 210308-04:26:54,524 nipype.workflow INFO:
# 	 Workflow emc_correction settings: ['check', 'execution', 'logging', 'monitoring']
# 210308-04:26:54,555 nipype.workflow INFO:
# 	 Running in parallel.
# 210308-04:26:54,560 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:26:54,631 nipype.workflow INFO:
# 	 [Job 0] Cached (emc_correction.emc_wf.patch2self_node).
# 210308-04:26:54,632 nipype.workflow INFO:
# 	 [Job 3] Cached (emc_correction.emc_wf.emc_vectors_node).
# 210308-04:26:54,634 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:26:54,707 nipype.workflow INFO:
# 	 [Job 1] Cached (emc_correction.emc_wf.dwi_reference_wf.validate).
# 210308-04:26:54,709 nipype.workflow INFO:
# 	 [Job 2] Cached (emc_correction.emc_wf.split_dwis_node).
# 210308-04:26:54,711 nipype.workflow INFO:
# 	 [Job 22] Cached (emc_correction.emc_wf.extract_b0_node).
# 210308-04:26:54,781 nipype.workflow INFO:
# 	 [Job 4] Cached (emc_correction.emc_wf.dwi_reference_wf.extract_b0).
# 210308-04:26:54,784 nipype.workflow INFO:
# 	 [Job 21] Cached (emc_correction.emc_wf.prune_b0s_from_dwis_node).
# 210308-04:26:54,785 nipype.workflow INFO:
# 	 [Job 23] Cached (emc_correction.emc_wf.split_b0s_node).
# 210308-04:26:54,787 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:26:54,854 nipype.workflow INFO:
# 	 [Job 5] Cached (emc_correction.emc_wf.dwi_reference_wf.reg_b0).
# 210308-04:26:54,921 nipype.workflow INFO:
# 	 [Job 6] Cached (emc_correction.emc_wf.dwi_reference_wf.pre_mask).
# 210308-04:26:54,989 nipype.workflow INFO:
# 	 [Job 7] Cached (emc_correction.emc_wf.dwi_reference_wf.rescale_b0).
# 210308-04:26:55,173 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.n4_correct
# 210308-04:27:02,552 nipype.workflow INFO:
# 	 [Job 8] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.n4_correct).
# 210308-04:27:02,555 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:02,624 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_first_pass
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.normalize
# 210308-04:27:04,557 nipype.workflow INFO:
# 	 [Job 9] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.normalize).
# 210308-04:27:04,559 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_first_pass
# 210308-04:27:05,428 nipype.workflow INFO:
# 	 [Job 10] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_first_pass).
# 210308-04:27:05,430 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:05,499 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_first_dilate
# 210308-04:27:10,897 nipype.workflow INFO:
# 	 [Job 11] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_first_dilate).
# 210308-04:27:10,899 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:10,967 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_first_mask
# 210308-04:27:11,567 nipype.workflow INFO:
# 	 [Job 12] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_first_mask).
# 210308-04:27:11,568 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:11,636 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.unifize
# 210308-04:27:13,74 nipype.workflow INFO:
# 	 [Job 13] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.unifize).
# 210308-04:27:13,76 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:13,147 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.13/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.fixhdr_unifize
# 210308-04:27:15,233 nipype.workflow INFO:
# 	 [Job 14] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.fixhdr_unifize).
# 210308-04:27:15,234 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:15,301 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_second_pass
# 210308-04:27:17,389 nipype.workflow INFO:
# 	 [Job 15] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.skullstrip_second_pass).
# 210308-04:27:17,390 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:17,456 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.13/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.fixhdr_skullstrip2
# 210308-04:27:19,312 nipype.workflow INFO:
# 	 [Job 16] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.fixhdr_skullstrip2).
# 210308-04:27:19,313 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:19,381 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.combine_masks
# 210308-04:27:21,511 nipype.workflow INFO:
# 	 [Job 17] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.combine_masks).
# 210308-04:27:21,513 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:21,582 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.apply_mask
#                        * emc_correction.emc_wf.mask_4d_node
# 210308-04:27:23,626 nipype.workflow INFO:
# 	 [Job 20] Completed (emc_correction.emc_wf.dwi_reference_wf.enhance_and_skullstrip_dwi_wf.apply_mask).
# 210308-04:27:23,628 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.mask_4d_node
# 210308-04:27:23,708 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.reg_000
#                        * emc_correction.emc_wf.mask_4d_node
# 210308-04:27:26,997 nipype.workflow INFO:
# 	 [Job 18] Completed (emc_correction.emc_wf.mask_4d_node).
# 210308-04:27:26,998 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.reg_000
# 210308-04:27:27,77 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.split_dwis_masked_node
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.reg_000
# 210308-04:27:29,438 nipype.workflow INFO:
# 	 [Job 19] Completed (emc_correction.emc_wf.split_dwis_masked_node).
# 210308-04:27:29,440 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.reg_000
# 210308-04:27:32,171 nipype.workflow INFO:
# 	 [Job 24] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.reg_000).
# 210308-04:27:32,172 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:32,240 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.averaged_images
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.transforms_to_list
# 210308-04:27:34,659 nipype.workflow INFO:
# 	 [Job 25] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.transforms_to_list).
# 210308-04:27:34,661 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.averaged_images
# 210308-04:27:34,733 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.avg_affine
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.averaged_images
# 210308-04:27:35,271 nipype.workflow INFO:
# 	 [Job 28] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.averaged_images).
# 210308-04:27:35,273 nipype.workflow INFO:
# 	 [Job 26] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.avg_affine).
# 210308-04:27:35,274 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:35,343 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.to_list
# 210308-04:27:35,676 nipype.workflow INFO:
# 	 [Job 27] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.to_list).
# 210308-04:27:35,677 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:35,745 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.invert_average
# 210308-04:27:38,297 nipype.workflow INFO:
# 	 [Job 29] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_000.invert_average).
# 210308-04:27:38,299 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:38,368 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.reg_001
# 210308-04:27:43,556 nipype.workflow INFO:
# 	 [Job 30] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.reg_001).
# 210308-04:27:43,557 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:43,625 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.averaged_images
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.transforms_to_list
# 210308-04:27:45,604 nipype.workflow INFO:
# 	 [Job 31] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.transforms_to_list).
# 210308-04:27:45,605 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.averaged_images
# 210308-04:27:45,676 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.avg_affine
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.averaged_images
# 210308-04:27:46,147 nipype.workflow INFO:
# 	 [Job 34] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.averaged_images).
# 210308-04:27:46,148 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.avg_affine
# 210308-04:27:46,351 nipype.workflow INFO:
# 	 [Job 32] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.avg_affine).
# 210308-04:27:46,352 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:46,422 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.to_list
# 210308-04:27:46,756 nipype.workflow INFO:
# 	 [Job 33] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.to_list).
# 210308-04:27:46,758 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:46,826 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.invert_average
# 210308-04:27:49,366 nipype.workflow INFO:
# 	 [Job 35] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_001.invert_average).
# 210308-04:27:49,367 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:49,441 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.reg_002
# 210308-04:27:54,707 nipype.workflow INFO:
# 	 [Job 36] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.reg_002).
# 210308-04:27:54,708 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:27:54,776 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.43/28.23, Free processors: 28/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.averaged_images
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.transforms_to_list
#                        * emc_correction.emc_wf.match_transforms_node
#                        * emc_correction.emc_wf.merge_b0s_node
# 210308-04:28:00,193 nipype.workflow INFO:
# 	 [Job 39] Completed (emc_correction.emc_wf.match_transforms_node).
# 210308-04:28:00,195 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 29/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.averaged_images
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.transforms_to_list
#                        * emc_correction.emc_wf.merge_b0s_node
# 210308-04:28:00,263 nipype.workflow INFO:
# 	 [Job 37] Completed (emc_correction.emc_wf.merge_b0s_node).
# 210308-04:28:00,265 nipype.workflow INFO:
# 	 [Job 60] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.transforms_to_list).
# 210308-04:28:00,266 nipype.workflow INFO:
# 	 [Job 63] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.averaged_images).
# 210308-04:28:00,268 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:00,338 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 29/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.avg_affine
#                        * emc_correction.emc_wf.b0_median
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:00,759 nipype.workflow INFO:
# 	 [Job 61] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.avg_affine).
# 210308-04:28:00,760 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_median
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:00,832 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 29/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.to_list
#                        * emc_correction.emc_wf.b0_median
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:01,180 nipype.workflow INFO:
# 	 [Job 62] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.to_list).
# 210308-04:28:01,182 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_median
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:01,252 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 29/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.invert_average
#                        * emc_correction.emc_wf.b0_median
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:02,214 nipype.workflow INFO:
# 	 [Job 64] Completed (emc_correction.emc_wf.b0_emc_wf.iterative_alignment_002.invert_average).
# 210308-04:28:02,216 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_median
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:02,297 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 29/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
#                        * emc_correction.emc_wf.b0_median
#                        * emc_correction.emc_wf.b0_based_vector_transforms
# 210308-04:28:02,373 nipype.workflow INFO:
# 	 [Job 41] Completed (emc_correction.emc_wf.b0_based_vector_transforms).
# 210308-04:28:02,375 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
#                        * emc_correction.emc_wf.b0_median
# 210308-04:28:02,918 nipype.workflow INFO:
# 	 [Job 38] Completed (emc_correction.emc_wf.b0_median).
# 210308-04:28:02,920 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
# 210308-04:28:03,0 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 31 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
# 210308-04:28:03,90 nipype.workflow INFO:
# 	 [MultiProc] Running 32 tasks, and 0 jobs ready. Free memory (GB): 21.83/28.23, Free processors: 0/32.
#                      Currently running:
#                        * _b0_based_image_transforms30
#                        * _b0_based_image_transforms29
#                        * _b0_based_image_transforms28
#                        * _b0_based_image_transforms27
#                        * _b0_based_image_transforms26
#                        * _b0_based_image_transforms25
#                        * _b0_based_image_transforms24
#                        * _b0_based_image_transforms23
#                        * _b0_based_image_transforms22
#                        * _b0_based_image_transforms21
#                        * _b0_based_image_transforms20
#                        * _b0_based_image_transforms19
#                        * _b0_based_image_transforms18
#                        * _b0_based_image_transforms17
#                        * _b0_based_image_transforms16
#                        * _b0_based_image_transforms15
#                        * _b0_based_image_transforms14
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms12
#                        * _b0_based_image_transforms11
#                        * _b0_based_image_transforms10
#                        * _b0_based_image_transforms9
#                        * _b0_based_image_transforms8
#                        * _b0_based_image_transforms7
#                        * _b0_based_image_transforms6
#                        * _b0_based_image_transforms5
#                        * _b0_based_image_transforms4
#                        * _b0_based_image_transforms3
#                        * _b0_based_image_transforms2
#                        * _b0_based_image_transforms1
#                        * _b0_based_image_transforms0
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
# 210308-04:28:03,592 nipype.workflow INFO:
# 	 [Job 75] Completed (_b0_based_image_transforms9).
# 210308-04:28:03,595 nipype.workflow INFO:
# 	 [MultiProc] Running 31 tasks, and 0 jobs ready. Free memory (GB): 22.03/28.23, Free processors: 1/32.
#                      Currently running:
#                        * _b0_based_image_transforms30
#                        * _b0_based_image_transforms29
#                        * _b0_based_image_transforms28
#                        * _b0_based_image_transforms27
#                        * _b0_based_image_transforms26
#                        * _b0_based_image_transforms25
#                        * _b0_based_image_transforms24
#                        * _b0_based_image_transforms23
#                        * _b0_based_image_transforms22
#                        * _b0_based_image_transforms21
#                        * _b0_based_image_transforms20
#                        * _b0_based_image_transforms19
#                        * _b0_based_image_transforms18
#                        * _b0_based_image_transforms17
#                        * _b0_based_image_transforms16
#                        * _b0_based_image_transforms15
#                        * _b0_based_image_transforms14
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms12
#                        * _b0_based_image_transforms11
#                        * _b0_based_image_transforms10
#                        * _b0_based_image_transforms8
#                        * _b0_based_image_transforms7
#                        * _b0_based_image_transforms6
#                        * _b0_based_image_transforms5
#                        * _b0_based_image_transforms4
#                        * _b0_based_image_transforms3
#                        * _b0_based_image_transforms2
#                        * _b0_based_image_transforms1
#                        * _b0_based_image_transforms0
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
# 210308-04:28:04,36 nipype.workflow INFO:
# 	 [Job 68] Completed (_b0_based_image_transforms2).
# 210308-04:28:04,41 nipype.workflow INFO:
# 	 [Job 70] Completed (_b0_based_image_transforms4).
# 210308-04:28:04,43 nipype.workflow INFO:
# 	 [Job 76] Completed (_b0_based_image_transforms10).
# 210308-04:28:04,45 nipype.workflow INFO:
# 	 [Job 77] Completed (_b0_based_image_transforms11).
# 210308-04:28:04,48 nipype.workflow INFO:
# 	 [Job 80] Completed (_b0_based_image_transforms14).
# 210308-04:28:04,50 nipype.workflow INFO:
# 	 [Job 81] Completed (_b0_based_image_transforms15).
# 210308-04:28:04,53 nipype.workflow INFO:
# 	 [Job 82] Completed (_b0_based_image_transforms16).
# 210308-04:28:04,55 nipype.workflow INFO:
# 	 [Job 83] Completed (_b0_based_image_transforms17).
# 210308-04:28:04,58 nipype.workflow INFO:
# 	 [Job 86] Completed (_b0_based_image_transforms20).
# 210308-04:28:04,59 nipype.workflow INFO:
# 	 [Job 87] Completed (_b0_based_image_transforms21).
# 210308-04:28:04,60 nipype.workflow INFO:
# 	 [Job 88] Completed (_b0_based_image_transforms22).
# 210308-04:28:04,60 nipype.workflow INFO:
# 	 [Job 95] Completed (_b0_based_image_transforms29).
# 210308-04:28:04,62 nipype.workflow INFO:
# 	 [MultiProc] Running 19 tasks, and 0 jobs ready. Free memory (GB): 24.43/28.23, Free processors: 13/32.
#                      Currently running:
#                        * _b0_based_image_transforms30
#                        * _b0_based_image_transforms28
#                        * _b0_based_image_transforms27
#                        * _b0_based_image_transforms26
#                        * _b0_based_image_transforms25
#                        * _b0_based_image_transforms24
#                        * _b0_based_image_transforms23
#                        * _b0_based_image_transforms19
#                        * _b0_based_image_transforms18
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms12
#                        * _b0_based_image_transforms8
#                        * _b0_based_image_transforms7
#                        * _b0_based_image_transforms6
#                        * _b0_based_image_transforms5
#                        * _b0_based_image_transforms3
#                        * _b0_based_image_transforms1
#                        * _b0_based_image_transforms0
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
# 210308-04:28:04,189 nipype.workflow INFO:
# 	 [Job 71] Completed (_b0_based_image_transforms5).
# 210308-04:28:04,191 nipype.workflow INFO:
# 	 [Job 73] Completed (_b0_based_image_transforms7).
# 210308-04:28:04,193 nipype.workflow INFO:
# 	 [Job 94] Completed (_b0_based_image_transforms28).
# 210308-04:28:04,195 nipype.workflow INFO:
# 	 [Job 96] Completed (_b0_based_image_transforms30).
# 210308-04:28:04,198 nipype.workflow INFO:
# 	 [MultiProc] Running 15 tasks, and 0 jobs ready. Free memory (GB): 25.23/28.23, Free processors: 17/32.
#                      Currently running:
#                        * _b0_based_image_transforms27
#                        * _b0_based_image_transforms26
#                        * _b0_based_image_transforms25
#                        * _b0_based_image_transforms24
#                        * _b0_based_image_transforms23
#                        * _b0_based_image_transforms19
#                        * _b0_based_image_transforms18
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms12
#                        * _b0_based_image_transforms8
#                        * _b0_based_image_transforms6
#                        * _b0_based_image_transforms3
#                        * _b0_based_image_transforms1
#                        * _b0_based_image_transforms0
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
# 210308-04:28:04,295 nipype.workflow INFO:
# 	 [Job 69] Completed (_b0_based_image_transforms3).
# 210308-04:28:04,298 nipype.workflow INFO:
# 	 [Job 72] Completed (_b0_based_image_transforms6).
# 210308-04:28:04,299 nipype.workflow INFO:
# 	 [Job 89] Completed (_b0_based_image_transforms23).
# 210308-04:28:04,300 nipype.workflow INFO:
# 	 [Job 90] Completed (_b0_based_image_transforms24).
# 210308-04:28:04,301 nipype.workflow INFO:
# 	 [Job 91] Completed (_b0_based_image_transforms25).
# 210308-04:28:04,301 nipype.workflow INFO:
# 	 [Job 92] Completed (_b0_based_image_transforms26).
# 210308-04:28:04,302 nipype.workflow INFO:
# 	 [Job 93] Completed (_b0_based_image_transforms27).
# 210308-04:28:04,304 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 0 jobs ready. Free memory (GB): 26.63/28.23, Free processors: 24/32.
#                      Currently running:
#                        * _b0_based_image_transforms19
#                        * _b0_based_image_transforms18
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms12
#                        * _b0_based_image_transforms8
#                        * _b0_based_image_transforms1
#                        * _b0_based_image_transforms0
#                        * emc_correction.emc_wf.b0_emc_wf.iteration_templates
# 210308-04:28:04,945 nipype.workflow INFO:
# 	 [Job 65] Completed (emc_correction.emc_wf.b0_emc_wf.iteration_templates).
# 210308-04:28:04,946 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 0 jobs ready. Free memory (GB): 26.83/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _b0_based_image_transforms19
#                        * _b0_based_image_transforms18
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms12
#                        * _b0_based_image_transforms8
#                        * _b0_based_image_transforms1
#                        * _b0_based_image_transforms0
# 210308-04:28:06,160 nipype.workflow INFO:
# 	 [Job 78] Completed (_b0_based_image_transforms12).
# 210308-04:28:06,162 nipype.workflow INFO:
# 	 [Job 84] Completed (_b0_based_image_transforms18).
# 210308-04:28:06,163 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 27.23/28.23, Free processors: 27/32.
#                      Currently running:
#                        * _b0_based_image_transforms19
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms8
#                        * _b0_based_image_transforms1
#                        * _b0_based_image_transforms0
# 210308-04:28:06,231 nipype.workflow INFO:
# 	 [Job 67] Completed (_b0_based_image_transforms1).
# 210308-04:28:06,233 nipype.workflow INFO:
# 	 [Job 74] Completed (_b0_based_image_transforms8).
# 210308-04:28:06,234 nipype.workflow INFO:
# 	 [Job 85] Completed (_b0_based_image_transforms19).
# 210308-04:28:06,235 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * _b0_based_image_transforms13
#                        * _b0_based_image_transforms0
# 210308-04:28:06,303 nipype.workflow INFO:
# 	 [Job 66] Completed (_b0_based_image_transforms0).
# 210308-04:28:06,304 nipype.workflow INFO:
# 	 [Job 79] Completed (_b0_based_image_transforms13).
# 210308-04:28:06,306 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:28:06,378 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.b0_based_image_transforms
# 210308-04:28:06,716 nipype.workflow INFO:
# 	 [Job 40] Completed (emc_correction.emc_wf.b0_based_image_transforms).
# 210308-04:28:06,718 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:28:06,845 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 30 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:28:06,932 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 23 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis6
#                        * _predict_dwis5
#                        * _predict_dwis4
#                        * _predict_dwis3
#                        * _predict_dwis2
#                        * _predict_dwis1
#                        * _predict_dwis0
# 210308-04:28:14,904 nipype.workflow INFO:
# 	 [Job 102] Completed (_predict_dwis5).
# 210308-04:28:14,906 nipype.workflow INFO:
# 	 [Job 103] Completed (_predict_dwis6).
# 210308-04:28:14,908 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 23 jobs ready. Free memory (GB): 8.23/28.23, Free processors: 27/32.
#                      Currently running:
#                        * _predict_dwis4
#                        * _predict_dwis3
#                        * _predict_dwis2
#                        * _predict_dwis1
#                        * _predict_dwis0
# 210308-04:28:14,984 nipype.workflow INFO:
# 	 [Job 97] Completed (_predict_dwis0).
# 210308-04:28:14,986 nipype.workflow INFO:
# 	 [Job 99] Completed (_predict_dwis2).
# 210308-04:28:14,987 nipype.workflow INFO:
# 	 [Job 100] Completed (_predict_dwis3).
# 210308-04:28:14,988 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 21 jobs ready. Free memory (GB): 12.23/28.23, Free processors: 28/32.
#                      Currently running:
#                        * _predict_dwis8
#                        * _predict_dwis7
#                        * _predict_dwis4
#                        * _predict_dwis1
# 210308-04:28:15,62 nipype.workflow INFO:
# 	 [Job 101] Completed (_predict_dwis4).
# 210308-04:28:15,64 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 18 jobs ready. Free memory (GB): 4.23/28.23, Free processors: 26/32.
#                      Currently running:
#                        * _predict_dwis11
#                        * _predict_dwis10
#                        * _predict_dwis9
#                        * _predict_dwis8
#                        * _predict_dwis7
#                        * _predict_dwis1
# 210308-04:28:15,137 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 17 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis12
#                        * _predict_dwis11
#                        * _predict_dwis10
#                        * _predict_dwis9
#                        * _predict_dwis8
#                        * _predict_dwis7
#                        * _predict_dwis1
# 210308-04:28:17,104 nipype.workflow INFO:
# 	 [Job 98] Completed (_predict_dwis1).
# 210308-04:28:17,106 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 17 jobs ready. Free memory (GB): 4.23/28.23, Free processors: 26/32.
#                      Currently running:
#                        * _predict_dwis12
#                        * _predict_dwis11
#                        * _predict_dwis10
#                        * _predict_dwis9
#                        * _predict_dwis8
#                        * _predict_dwis7
# 210308-04:28:17,336 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 16 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis13
#                        * _predict_dwis12
#                        * _predict_dwis11
#                        * _predict_dwis10
#                        * _predict_dwis9
#                        * _predict_dwis8
#                        * _predict_dwis7
# 210308-04:28:22,460 nipype.workflow INFO:
# 	 [Job 104] Completed (_predict_dwis7).
# 210308-04:28:22,461 nipype.workflow INFO:
# 	 [Job 105] Completed (_predict_dwis8).
# 210308-04:28:22,462 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 16 jobs ready. Free memory (GB): 8.23/28.23, Free processors: 27/32.
#                      Currently running:
#                        * _predict_dwis13
#                        * _predict_dwis12
#                        * _predict_dwis11
#                        * _predict_dwis10
#                        * _predict_dwis9
# 210308-04:28:22,607 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 14 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis15
#                        * _predict_dwis14
#                        * _predict_dwis13
#                        * _predict_dwis12
#                        * _predict_dwis11
#                        * _predict_dwis10
#                        * _predict_dwis9
# 210308-04:28:22,829 nipype.workflow INFO:
# 	 [Job 106] Completed (_predict_dwis9).
# 210308-04:28:22,830 nipype.workflow INFO:
# 	 [Job 108] Completed (_predict_dwis11).
# 210308-04:28:22,831 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 14 jobs ready. Free memory (GB): 8.23/28.23, Free processors: 27/32.
#                      Currently running:
#                        * _predict_dwis15
#                        * _predict_dwis14
#                        * _predict_dwis13
#                        * _predict_dwis12
#                        * _predict_dwis10
# 210308-04:28:22,928 nipype.workflow INFO:
# 	 [Job 107] Completed (_predict_dwis10).
# 210308-04:28:22,929 nipype.workflow INFO:
# 	 [Job 109] Completed (_predict_dwis12).
# 210308-04:28:22,931 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 12 jobs ready. Free memory (GB): 8.23/28.23, Free processors: 27/32.
#                      Currently running:
#                        * _predict_dwis17
#                        * _predict_dwis16
#                        * _predict_dwis15
#                        * _predict_dwis14
#                        * _predict_dwis13
# 210308-04:28:23,28 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 10 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis19
#                        * _predict_dwis18
#                        * _predict_dwis17
#                        * _predict_dwis16
#                        * _predict_dwis15
#                        * _predict_dwis14
#                        * _predict_dwis13
# 210308-04:28:26,331 nipype.workflow INFO:
# 	 [Job 110] Completed (_predict_dwis13).
# 210308-04:28:26,332 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 10 jobs ready. Free memory (GB): 4.23/28.23, Free processors: 26/32.
#                      Currently running:
#                        * _predict_dwis19
#                        * _predict_dwis18
#                        * _predict_dwis17
#                        * _predict_dwis16
#                        * _predict_dwis15
#                        * _predict_dwis14
# 210308-04:28:26,417 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 9 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis20
#                        * _predict_dwis19
#                        * _predict_dwis18
#                        * _predict_dwis17
#                        * _predict_dwis16
#                        * _predict_dwis15
#                        * _predict_dwis14
# 210308-04:28:30,266 nipype.workflow INFO:
# 	 [Job 111] Completed (_predict_dwis14).
# 210308-04:28:30,270 nipype.workflow INFO:
# 	 [Job 112] Completed (_predict_dwis15).
# 210308-04:28:30,272 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 9 jobs ready. Free memory (GB): 8.23/28.23, Free processors: 27/32.
#                      Currently running:
#                        * _predict_dwis20
#                        * _predict_dwis19
#                        * _predict_dwis18
#                        * _predict_dwis17
#                        * _predict_dwis16
# 210308-04:28:30,416 nipype.workflow INFO:
# 	 [Job 115] Completed (_predict_dwis18).
# 210308-04:28:30,418 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 7 jobs ready. Free memory (GB): 4.23/28.23, Free processors: 26/32.
#                      Currently running:
#                        * _predict_dwis22
#                        * _predict_dwis21
#                        * _predict_dwis20
#                        * _predict_dwis19
#                        * _predict_dwis17
#                        * _predict_dwis16
# 210308-04:28:30,495 nipype.workflow INFO:
# 	 [Job 113] Completed (_predict_dwis16).
# 210308-04:28:30,496 nipype.workflow INFO:
# 	 [Job 114] Completed (_predict_dwis17).
# 210308-04:28:30,497 nipype.workflow INFO:
# 	 [Job 116] Completed (_predict_dwis19).
# 210308-04:28:30,498 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 6 jobs ready. Free memory (GB): 12.23/28.23, Free processors: 28/32.
#                      Currently running:
#                        * _predict_dwis23
#                        * _predict_dwis22
#                        * _predict_dwis21
#                        * _predict_dwis20
# 210308-04:28:30,578 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 3 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis26
#                        * _predict_dwis25
#                        * _predict_dwis24
#                        * _predict_dwis23
#                        * _predict_dwis22
#                        * _predict_dwis21
#                        * _predict_dwis20
# 210308-04:28:33,534 nipype.workflow INFO:
# 	 [Job 117] Completed (_predict_dwis20).
# 210308-04:28:33,535 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 3 jobs ready. Free memory (GB): 4.23/28.23, Free processors: 26/32.
#                      Currently running:
#                        * _predict_dwis26
#                        * _predict_dwis25
#                        * _predict_dwis24
#                        * _predict_dwis23
#                        * _predict_dwis22
#                        * _predict_dwis21
# 210308-04:28:33,621 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 2 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 25/32.
#                      Currently running:
#                        * _predict_dwis27
#                        * _predict_dwis26
#                        * _predict_dwis25
#                        * _predict_dwis24
#                        * _predict_dwis23
#                        * _predict_dwis22
#                        * _predict_dwis21
# 210308-04:28:37,956 nipype.workflow INFO:
# 	 [Job 123] Completed (_predict_dwis26).
# 210308-04:28:37,958 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 2 jobs ready. Free memory (GB): 4.23/28.23, Free processors: 26/32.
#                      Currently running:
#                        * _predict_dwis27
#                        * _predict_dwis25
#                        * _predict_dwis24
#                        * _predict_dwis23
#                        * _predict_dwis22
#                        * _predict_dwis21
# 210308-04:28:38,33 nipype.workflow INFO:
# 	 [Job 118] Completed (_predict_dwis21).
# 210308-04:28:38,34 nipype.workflow INFO:
# 	 [Job 119] Completed (_predict_dwis22).
# 210308-04:28:38,35 nipype.workflow INFO:
# 	 [Job 120] Completed (_predict_dwis23).
# 210308-04:28:38,35 nipype.workflow INFO:
# 	 [Job 121] Completed (_predict_dwis24).
# 210308-04:28:38,36 nipype.workflow INFO:
# 	 [Job 122] Completed (_predict_dwis25).
# 210308-04:28:38,37 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 20.23/28.23, Free processors: 30/32.
#                      Currently running:
#                        * _predict_dwis28
#                        * _predict_dwis27
# 210308-04:28:38,111 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 16.23/28.23, Free processors: 29/32.
#                      Currently running:
#                        * _predict_dwis29
#                        * _predict_dwis28
#                        * _predict_dwis27
# 210308-04:28:40,16 nipype.workflow INFO:
# 	 [Job 124] Completed (_predict_dwis27).
# 210308-04:28:40,17 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 20.23/28.23, Free processors: 30/32.
#                      Currently running:
#                        * _predict_dwis29
#                        * _predict_dwis28
# 210308-04:28:44,274 nipype.workflow INFO:
# 	 [Job 125] Completed (_predict_dwis28).
# 210308-04:28:44,276 nipype.workflow INFO:
# 	 [Job 126] Completed (_predict_dwis29).
# 210308-04:28:44,277 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:28:44,352 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 24.23/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_model_emc_wf.initial_model_iteration.predict_dwis
# 210308-04:28:44,706 nipype.workflow INFO:
# 	 [Job 42] Completed (emc_correction.emc_wf.dwi_model_emc_wf.initial_model_iteration.predict_dwis).
# 210308-04:28:44,707 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:28:44,800 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 30 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.
# 210308-04:28:44,882 nipype.workflow INFO:
# 	 [MultiProc] Running 14 tasks, and 16 jobs ready. Free memory (GB): 0.23/28.23, Free processors: 18/32.
#                      Currently running:
#                        * _register_to_predicted13
# ...
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images29
#                        * _motion_correct_images28
#                        * _motion_correct_images27
#                        * _motion_correct_images26
#                        * _motion_correct_images25
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images21
#                        * _motion_correct_images20
#                        * _motion_correct_images19
#                        * _motion_correct_images18
#                        * _motion_correct_images17
#                        * _motion_correct_images16
#                        * _motion_correct_images15
#                        * _motion_correct_images14
#                        * _motion_correct_images13
#                        * _motion_correct_images12
#                        * _motion_correct_images11
#                        * _motion_correct_images10
#                        * _motion_correct_images9
#                        * _motion_correct_images8
#                        * _motion_correct_images7
#                        * _motion_correct_images6
#                        * _motion_correct_images5
#                        * _motion_correct_images4
#                        * _motion_correct_images3
#                        * _motion_correct_images2
#                        * _motion_correct_images1
#                        * _motion_correct_images0
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:57,914 nipype.workflow INFO:
# 	 [Job 218] Completed (_motion_correct_images1).
# 210309-00:19:57,917 nipype.workflow INFO:
# 	 [MultiProc] Running 31 tasks, and 0 jobs ready. Free memory (GB): 22.03/28.23, Free processors: 1/32.
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images29
#                        * _motion_correct_images28
#                        * _motion_correct_images27
#                        * _motion_correct_images26
#                        * _motion_correct_images25
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images21
#                        * _motion_correct_images20
#                        * _motion_correct_images19
#                        * _motion_correct_images18
#                        * _motion_correct_images17
#                        * _motion_correct_images16
#                        * _motion_correct_images15
#                        * _motion_correct_images14
#                        * _motion_correct_images13
#                        * _motion_correct_images12
#                        * _motion_correct_images11
#                        * _motion_correct_images10
#                        * _motion_correct_images9
#                        * _motion_correct_images8
#                        * _motion_correct_images7
#                        * _motion_correct_images6
#                        * _motion_correct_images5
#                        * _motion_correct_images4
#                        * _motion_correct_images3
#                        * _motion_correct_images2
#                        * _motion_correct_images0
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,185 nipype.workflow INFO:
# 	 [Job 227] Completed (_motion_correct_images10).
# 210309-00:19:58,186 nipype.workflow INFO:
# 	 [Job 232] Completed (_motion_correct_images15).
# 210309-00:19:58,188 nipype.workflow INFO:
# 	 [MultiProc] Running 29 tasks, and 0 jobs ready. Free memory (GB): 22.43/28.23, Free processors: 3/32.
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images29
#                        * _motion_correct_images28
#                        * _motion_correct_images27
#                        * _motion_correct_images26
#                        * _motion_correct_images25
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images21
#                        * _motion_correct_images20
#                        * _motion_correct_images19
#                        * _motion_correct_images18
#                        * _motion_correct_images17
#                        * _motion_correct_images16
#                        * _motion_correct_images14
#                        * _motion_correct_images13
#                        * _motion_correct_images12
#                        * _motion_correct_images11
#                        * _motion_correct_images9
#                        * _motion_correct_images8
#                        * _motion_correct_images7
#                        * _motion_correct_images6
#                        * _motion_correct_images5
#                        * _motion_correct_images4
#                        * _motion_correct_images3
#                        * _motion_correct_images2
#                        * _motion_correct_images0
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,279 nipype.workflow INFO:
# 	 [Job 217] Completed (_motion_correct_images0).
# 210309-00:19:58,280 nipype.workflow INFO:
# 	 [Job 223] Completed (_motion_correct_images6).
# 210309-00:19:58,281 nipype.workflow INFO:
# 	 [Job 242] Completed (_motion_correct_images25).
# 210309-00:19:58,282 nipype.workflow INFO:
# 	 [Job 246] Completed (_motion_correct_images29).
# 210309-00:19:58,283 nipype.workflow INFO:
# 	 [MultiProc] Running 25 tasks, and 0 jobs ready. Free memory (GB): 23.23/28.23, Free processors: 7/32.
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images28
#                        * _motion_correct_images27
#                        * _motion_correct_images26
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images21
#                        * _motion_correct_images20
#                        * _motion_correct_images19
#                        * _motion_correct_images18
#                        * _motion_correct_images17
#                        * _motion_correct_images16
#                        * _motion_correct_images14
#                        * _motion_correct_images13
#                        * _motion_correct_images12
#                        * _motion_correct_images11
#                        * _motion_correct_images9
#                        * _motion_correct_images8
#                        * _motion_correct_images7
#                        * _motion_correct_images5
#                        * _motion_correct_images4
#                        * _motion_correct_images3
#                        * _motion_correct_images2
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,371 nipype.workflow INFO:
# 	 [Job 238] Completed (_motion_correct_images21).
# 210309-00:19:58,373 nipype.workflow INFO:
# 	 [MultiProc] Running 24 tasks, and 0 jobs ready. Free memory (GB): 23.43/28.23, Free processors: 8/32.
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images28
#                        * _motion_correct_images27
#                        * _motion_correct_images26
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images20
#                        * _motion_correct_images19
#                        * _motion_correct_images18
#                        * _motion_correct_images17
#                        * _motion_correct_images16
#                        * _motion_correct_images14
#                        * _motion_correct_images13
#                        * _motion_correct_images12
#                        * _motion_correct_images11
#                        * _motion_correct_images9
#                        * _motion_correct_images8
#                        * _motion_correct_images7
#                        * _motion_correct_images5
#                        * _motion_correct_images4
#                        * _motion_correct_images3
#                        * _motion_correct_images2
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,461 nipype.workflow INFO:
# 	 [Job 225] Completed (_motion_correct_images8).
# 210309-00:19:58,462 nipype.workflow INFO:
# 	 [Job 233] Completed (_motion_correct_images16).
# 210309-00:19:58,463 nipype.workflow INFO:
# 	 [Job 234] Completed (_motion_correct_images17).
# 210309-00:19:58,464 nipype.workflow INFO:
# 	 [Job 244] Completed (_motion_correct_images27).
# 210309-00:19:58,465 nipype.workflow INFO:
# 	 [MultiProc] Running 20 tasks, and 0 jobs ready. Free memory (GB): 24.23/28.23, Free processors: 12/32.
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images28
#                        * _motion_correct_images26
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images20
#                        * _motion_correct_images19
#                        * _motion_correct_images18
#                        * _motion_correct_images14
#                        * _motion_correct_images13
#                        * _motion_correct_images12
#                        * _motion_correct_images11
#                        * _motion_correct_images9
#                        * _motion_correct_images7
#                        * _motion_correct_images5
#                        * _motion_correct_images4
#                        * _motion_correct_images3
#                        * _motion_correct_images2
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,558 nipype.workflow INFO:
# 	 [Job 221] Completed (_motion_correct_images4).
# 210309-00:19:58,559 nipype.workflow INFO:
# 	 [Job 228] Completed (_motion_correct_images11).
# 210309-00:19:58,560 nipype.workflow INFO:
# 	 [Job 229] Completed (_motion_correct_images12).
# 210309-00:19:58,561 nipype.workflow INFO:
# 	 [Job 230] Completed (_motion_correct_images13).
# 210309-00:19:58,561 nipype.workflow INFO:
# 	 [Job 235] Completed (_motion_correct_images18).
# 210309-00:19:58,562 nipype.workflow INFO:
# 	 [Job 243] Completed (_motion_correct_images26).
# 210309-00:19:58,563 nipype.workflow INFO:
# 	 [Job 245] Completed (_motion_correct_images28).
# 210309-00:19:58,565 nipype.workflow INFO:
# 	 [MultiProc] Running 13 tasks, and 0 jobs ready. Free memory (GB): 25.63/28.23, Free processors: 19/32.
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images20
#                        * _motion_correct_images19
#                        * _motion_correct_images14
#                        * _motion_correct_images9
#                        * _motion_correct_images7
#                        * _motion_correct_images5
#                        * _motion_correct_images3
#                        * _motion_correct_images2
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,652 nipype.workflow INFO:
# 	 [Job 219] Completed (_motion_correct_images2).
# 210309-00:19:58,653 nipype.workflow INFO:
# 	 [Job 236] Completed (_motion_correct_images19).
# 210309-00:19:58,654 nipype.workflow INFO:
# 	 [Job 237] Completed (_motion_correct_images20).
# 210309-00:19:58,655 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 0 jobs ready. Free memory (GB): 26.23/28.23, Free processors: 22/32.
#                      Currently running:
#                        * _motion_correct_images30
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images22
#                        * _motion_correct_images14
#                        * _motion_correct_images9
#                        * _motion_correct_images7
#                        * _motion_correct_images5
#                        * _motion_correct_images3
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,745 nipype.workflow INFO:
# 	 [Job 224] Completed (_motion_correct_images7).
# 210309-00:19:58,746 nipype.workflow INFO:
# 	 [Job 231] Completed (_motion_correct_images14).
# 210309-00:19:58,747 nipype.workflow INFO:
# 	 [Job 239] Completed (_motion_correct_images22).
# 210309-00:19:58,748 nipype.workflow INFO:
# 	 [Job 247] Completed (_motion_correct_images30).
# 210309-00:19:58,749 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 0 jobs ready. Free memory (GB): 27.03/28.23, Free processors: 26/32.
#                      Currently running:
#                        * _motion_correct_images24
#                        * _motion_correct_images23
#                        * _motion_correct_images9
#                        * _motion_correct_images5
#                        * _motion_correct_images3
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,844 nipype.workflow INFO:
# 	 [Job 220] Completed (_motion_correct_images3).
# 210309-00:19:58,845 nipype.workflow INFO:
# 	 [Job 222] Completed (_motion_correct_images5).
# 210309-00:19:58,845 nipype.workflow INFO:
# 	 [Job 226] Completed (_motion_correct_images9).
# 210309-00:19:58,846 nipype.workflow INFO:
# 	 [Job 240] Completed (_motion_correct_images23).
# 210309-00:19:58,846 nipype.workflow INFO:
# 	 [Job 241] Completed (_motion_correct_images24).
# 210309-00:19:58,847 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:58,943 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.motion_correct_images
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:59,308 nipype.workflow INFO:
# 	 [Job 51] Completed (emc_correction.emc_wf.motion_correct_images).
# 210309-00:19:59,309 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:19:59,401 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 30/32.
#                      Currently running:
#                        * emc_correction.emc_wf.merge_EMC_corrected_dwis_node
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:20:03,152 nipype.workflow INFO:
# 	 [Job 52] Completed (emc_correction.emc_wf.merge_EMC_corrected_dwis_node).
# 210309-00:20:03,154 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 31/32.
#                      Currently running:
#                        * emc_correction.emc_wf.dwi_model_emc_wf.emc_report
# 210309-00:20:05,679 nipype.workflow INFO:
# 	 [Job 59] Completed (emc_correction.emc_wf.dwi_model_emc_wf.emc_report).
# 210309-00:20:05,681 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 32/32.

# %%
list(res.nodes())
